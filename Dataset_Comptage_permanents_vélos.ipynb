# %%
import pandas as pd

df=pd.read_csv("C:/Users/spotp/Downloads/comptages_velos_permanents.csv")
df_vf=df[df['territoire'] == 'Grenoble Alpes Metropole']

#print(df.info())
#print(df.head(3))
df_vf.head()
# Out:
#    id                                     nom_post                nom_comm  \
# 2  28                 (Echirolles) rue Victor Hugo              Échirolles
# 5  31             (SMLV) Pont d'Oxford - Afficheur  Saint-Martin-le-Vinoux
# 6  30  (Saint Martin d'Hères) Campus universitaire    Saint-Martin-d'Hères
# 7  32     (Pont de Claix) PEM l'Etoile - Afficheur        Le Pont-de-Claix
# 8  26                  (Meylan) Mairie / Afficheur                  Meylan
#
#    code_insee  modes  date_instal          localisation   type_compteur  \
# 2       38151  Velos     20201112       Rue Victor Hugo     Boucle_ZELT
# 5       38423  Velos     20220210         Pont d'Oxford  ZELT+Afficheur
# 6       38421  Velos     20220406  Campus Universitaire     Boucle_ZELT
# 7       38317  Velos     20210927              L'Etoile  ZELT+Afficheur
# 8       38229  Velos     20200918      Mairie de Meylan  ZELT+Afficheur
#
#      type_axe  tmj_2019  ...  jour_de_pointe_2021  jour_de_pointe_2020  \
# 2  chronovélo       NaN  ...               1135.0                528.0
# 5  voie verte       NaN  ...                  NaN                  NaN
# 6  chronovélo       NaN  ...                  NaN                  NaN
# 7  chronovélo       NaN  ...                521.0                  NaN
# 8  chronovélo       NaN  ...                990.0                964.0
#
#    jour_de_pointe_2019  date_pointe_2022  date_pointe_2021  date_pointe_2020  \
# 2                  NaN          20221018        20210907.0        20201118.0
# 5                  NaN          20221018               NaN               NaN
# 6                  NaN          20221018               NaN               NaN
# 7                  NaN          20221011        20211014.0               NaN
# 8                  NaN          20221018        20210908.0        20200923.0
#
#                  territoire  date_pointe_2019  fid  \
# 2  Grenoble Alpes Metropole               NaN    3
# 5  Grenoble Alpes Metropole               NaN    6
# 6  Grenoble Alpes Metropole               NaN    7
# 7  Grenoble Alpes Metropole               NaN    8
# 8  Grenoble Alpes Metropole               NaN    9
#
#                             geo_point_2d
# 2    45.15498351431255, 5.71241623986171
# 5  45.207988000018965, 5.702445999999999
# 6  45.186215000019004, 5.769533999999999
# 7   45.13781800001914, 5.702301000000001
# 8   45.20945100001895, 5.779065999999999
#
# [5 rows x 32 columns]

# %%
import pandas as pd

# Charger les données


# Afficher ou vérifier les premières lignes du nouveau DataFrame
colonnes=['nom_post', 'modes','localisation','type_compteur','type_axe','tmj_2019','tmj_2020','tmj_2021','tmj_2022']
colonnes_bis=['nom_post','localisation','type_axe','tmj_2019','tmj_2020','tmj_2021','tmj_2022']

print(df_vf[colonnes_bis].head(10))
# Out:
#                                        nom_post              localisation  \
# 2                  (Echirolles) rue Victor Hugo           Rue Victor Hugo
# 5              (SMLV) Pont d'Oxford - Afficheur             Pont d'Oxford
# 6   (Saint Martin d'Hères) Campus universitaire      Campus Universitaire
# 7      (Pont de Claix) PEM l'Etoile - Afficheur                  L'Etoile
# 8                   (Meylan) Mairie / Afficheur          Mairie de Meylan
# 9                (Saint Egreve) Digue - VV2 V63        Digue Saint-Egrève
# 10          (Seyssins) Digue - Passerelle Drac1    Passerelle de Seyssins
# 11              (Fontaine) Digue - Quai du Drac            Digue Fontaine
# 12            (Echirolles) Digue - Comboire V64            Digue Comboire
# 13         (Eybens) Rue P. Mendes France - eyb1  Rue Pierre Mendès France
#
#             type_axe  tmj_2019  tmj_2020  tmj_2021  tmj_2022
# 2         chronovélo       NaN     304.0     536.0       737
# 5         voie verte       NaN       NaN       NaN      1246
# 6         chronovélo       NaN       NaN       NaN       710
# 7         chronovélo       NaN       NaN     250.0       369
# 8         chronovélo       NaN     375.0     412.0       486
# 9         voie verte     143.0       NaN     330.0       410
# 10        passerelle     739.0     791.0     939.0      1054
# 11        voie verte     429.0    1097.0    1294.0      1488
# 12        voie verte     336.0     513.0     651.0       734
# 13  bidirectionnelle     471.0     493.0     522.0       634

# %% [markdown]
# #### Comme tous les compteurs n'ont pas été installés au même moment, il existe beaucoup de valeurs manquantes (NaN), il sera alors nécessaire de les ignorer au moment des analyses car il ne conviendrait pas de les remplacer par des zéros (fausseraient les résultats) de supprimer les lignes associées (trop nombreuses)
# #### Ce qu'il faudrait c'est donc au moment de faire les analyses, passer outre ces valeurs vides (si l'on cherche a avoir des moyennes par années ou par ville par exemple)

# %%
df_grenoble.to_csv("Comptage_vélos_Grenoble.csv")
